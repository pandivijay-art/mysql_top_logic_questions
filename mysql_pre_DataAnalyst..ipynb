# %% [markdown]
# ## what is offset?
# #### offset is used to skip the begainning rows based on the Values

# %% [markdown]
# ### what is the Cureent_timesatmp

# %% [markdown]
# #### current_timesatmp() - it's used to return the current time and Date in mysql

# %% [markdown]
# #### curtime() - its used to return the curtrent time

# %% [markdown]
# #### curdate() - its used to return the current Date

# %% [markdown]
# ### with - with is used to create temporary named result set(give the name for whole query) ,its called a cte(comman table expression)

# %% [markdown]
# ### Row_number() - is a window function , that assign a unique number of each rows with in a partition ,starting from 1.
# #### if you use row_number() we defenitly user over() ,over() - define the set of rows which a window function operates.

# %% [markdown]
# #### Importent Concept must known as a data Analyst/ data Scientist/ data Engineer

# %% [markdown]
# #### 1.DQl Commands:

# %% [markdown]
# * Select
# * From
# * where
# * Distinct
# * Order By
# * Group by
# * Having
# * Limit

# %% [markdown]
# #### 2.Aggrigate Function

# %% [markdown]
# COUNT()
# SUM()
# AVG()
# MIN()
# MAX()

# %% [markdown]
# ### 3.Joins

# %% [markdown]
# INNER JOIN
# LEFT JOIN
# RIGHT JOIN
# CROSS JOIN
# SELF JOIN
# * case if()
# * coalesce()
# * nullif()
# * subquery with (cte)
# *

# %% [markdown]
# ### Window Functions

# %% [markdown]
# ROW_NUMBER()
# RANK()
# DENSE_RANK()
# LAG()
# LEAD()
# OVER()
# PARTITION BY

# %% [markdown]
# ### DMl commands

# %% [markdown]
# INSERT
# UPDATE
# DELETE

# %% [markdown]
# ### Dql Commands

# %% [markdown]
# CREATE
# ALTER
# DROP
# TRUNCATE

# %% [markdown]
# ### FInal Path

# %% [markdown]
# 1. SELECT → 2. WHERE → 3. ORDER BY → 4. GROUP BY → 5. HAVING → 6. Aggregate Functions → 7. JOINs → 8. Subqueries → 9. CTE → 10. CASE → 11. Window Functions

# %% [markdown]
# ### 1.What is dataset and Data Base

# %% [markdown]
# ##### Data Base - stored and collected large amount of Data and manage , organise large Data.

# %% [markdown]
# #### Data set - stored collection of data (used it for specific purpose )

# %% [markdown]
# #### single table is called table

# %% [markdown]
# ### wild Cart Operater:

# %% [markdown]
# * LIKE ⭐⭐⭐⭐⭐ # like is the not wild cart operetr ,searching battern operater.
# * IN ⭐⭐⭐⭐⭐
# * BETWEEN ⭐⭐⭐⭐⭐
# * IS NULL ⭐⭐⭐⭐⭐
# * AND / OR / NOT ⭐⭐⭐⭐⭐
# * % / _ ⭐⭐⭐⭐⭐

# %% [markdown]
# ### like

# %% [markdown]
# * is a sql Wildcart operater.
# * search for the specific pattern within a String.
# * Why use % symbol
# *  % represents zero to more charcter in a string.
# *  start with "S%"
# *  end with "%S"
# *  betweeen the charcter "%s%"

# %% [markdown]
# ### Cross Join and Self Join

# %% [markdown]
# #### Cross Join Means combines Every row from the first table with every row from the second table.

# %% [markdown]
# ### Self Join

# %% [markdown]
# #### self join Means join which is table joined itself to compare relationship . Alias nessary

# %% [markdown]
# ### Over()

# %% [markdown]
# ### define the window function ,which row to consider for the calculations.

# %% [markdown]
# ### Rank()

# %% [markdown]
# #### Assigning a rank for each row Based on the Ordering ,if rows Values are equals rank assign same rank for tied Values. and skiipping the subsequent Number.

# %% [markdown]
# ### dense_rank()

# %% [markdown]
# #### assign the Rank for each rows Based on the Orders,and assign the same Rank for tied Values but without leaving Gapes in Ranking Sequences.

# %% [markdown]
# ### Row_Number()

# %% [markdown]
# #### Assign the unique values for each rows based on their Conditionsd.

# %% [markdown]
# ### group By

# %% [markdown]
# #### Arrange the Data into Groupes ,group by data ,but group by  it collapse multiple row into single row.

# %% [markdown]
# ### Particien By

# %% [markdown]
# #### Arrange the Data into Groupes ,group by data ,but particien By it not collapse the rows.

# %% [markdown]
# #### Stored Procedure

# %% [markdown]
# ### Stored Procedure is a Pre defined,set of sql statement stored in Data base ,and execute when we call it.

# %% [markdown]
# #### delimter

# %% [markdown]
# #### Delimiter is a character or symbol it is inticate end of the command .
# #### we can use both // and $$ symbol .it is a common symbol.

# %% [markdown]
# #### CTE(common Table Experssion)

# %% [markdown]
# ### cte is a temporary Name result ,we store the result in inside query .used do simplify and reuse the logic within a sql query.

# %% [markdown]
# ### with claues used to create temporary names before Create CTE.

# %% [markdown]
# ### Views:

# %% [markdown]
# #### view is Create a Virtual Table  Based on the saved Query .we resue this Table Multiple times .but Virtual Table not Contain Actual Data .

# %% [markdown]
# ### commit

# %% [markdown]
# ##### commit is used to permanently save a transaction,

# %% [markdown]
# #### Transaction:

# %% [markdown]
# #### A transaction is One or more Changes in DataBase.

# %% [markdown]
# #### RollBack:

# %% [markdown]
# #### undo the change Made in the Curretn Transction

# %% [markdown]
# ### Date_trunk

# %% [markdown]
# ##### Date_trunk it is used to bring the data into specific Lefel ,such as Month or year.
# ##### syntax:
# Date_trunc(Column_name,what we Want)

# %% [markdown]
# ### String Functions.

# %% [markdown]
# 1.upper() - upper functions is used to convert tha all charcters into upperCase.

# %% [markdown]
# 2.lower() - it is used to convert the all charcaters into Lower Case.

# %% [markdown]
# 3.Trim() - take expression and remove extra spaces from  staring and end spaces.

# %% [markdown]
# ### Date Functions

# %% [markdown]
# current_date() - return the current Date.

# %% [markdown]
# Date_diff() - calculte the Differend Between Dates.
# syntax: date_diff(date1,sate2,date_part)

# %% [markdown]
# Date_add() - it add the specific amount of time to Date.
# syntax: date_add(date,interval number date_part)
#
# ###### Interval means specifies how many amount of time you Want add or subtract.

# %% [markdown]
# Date_trunc() - used to bring the Data to specific Level ,such as month or year.

# %% [markdown]
# Extract() - extract the specific part of the date ,such as year,month or Date.
# syntax: extract(day from Date)

# %% [markdown]
# format_date() - it is used to format a date into a specific display format.syntax: format_date(format,Date)
